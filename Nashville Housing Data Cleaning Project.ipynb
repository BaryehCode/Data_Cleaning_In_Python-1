# %%
import pandas as pd
import numpy as np
from PIL import Image

# %%
img = Image.open('data-cleansing.jpg')    # Open image as PIL image object
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x400 at 0x17BEA386EB0>

# %% [markdown]
# __ABOUT THE DATASET__
#
# The dataset was downloaded form a random github account. The aim of this project it to use various methods available through python Pandas to clean up the data to a state where it is fit for Analysis and Visualization. The visualization aspect will be a separate project. This project is dedicated soley to Data Cleaning

# %% [markdown]
# __READING HOUSING CSV DATASET INTO JUPYTER__

# %%
df = pd.read_csv('nash_housing_data.csv')

# %% [markdown]
# __DISPLAYING FIRST FIVE ROWS__

# %%
df.head(5)
# Out:
#    UniqueID          ParcelID        LandUse  \
# 0       2045  007 00 0 125.00  SINGLE FAMILY
# 1      16918  007 00 0 130.00  SINGLE FAMILY
# 2      54582  007 00 0 138.00  SINGLE FAMILY
# 3      43070  007 00 0 143.00  SINGLE FAMILY
# 4      22714  007 00 0 149.00  SINGLE FAMILY
#
#                       PropertyAddress   SaleDate SalePrice    LegalReference  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE  09-Apr-13    240000  20130412-0036474
# 1  1832  FOX CHASE DR, GOODLETTSVILLE  10-Jun-14    366000  20140619-0053768
# 2  1864 FOX CHASE  DR, GOODLETTSVILLE  26-Sep-16    435000  20160927-0101718
# 3  1853  FOX CHASE DR, GOODLETTSVILLE  29-Jan-16    255000  20160129-0008913
# 4  1829  FOX CHASE DR, GOODLETTSVILLE  10-Oct-14    278000  20141015-0095255
#
#   SoldAsVacant                           OwnerName  \
# 0           No           FRAZIER, CYRENTHA LYNETTE
# 1           No             BONER, CHARLES & LESLIE
# 2           No           WILSON, JAMES E. & JOANNE
# ...

# %% [markdown]
# __UNDERSTANDING FEATURES OF THE DATASET__

# %%
df.shape
# Out:
# (56477, 19)

# %%
df.describe()
# Out:
#           UniqueID        Acreage     LandValue  BuildingValue    TotalValue  \
# count  56477.000000  26015.000000  2.601500e+04   2.601500e+04  2.601500e+04
# mean   28334.001133      0.498923  6.906856e+04   1.607847e+05  2.323754e+05
# std    16352.590651      1.570454  1.060401e+05   2.067999e+05  2.810643e+05
# min        0.000000      0.010000  1.000000e+02   0.000000e+00  1.000000e+02
# 25%    14186.000000      0.180000  2.100000e+04   7.590000e+04  1.028000e+05
# 50%    28313.000000      0.270000  2.880000e+04   1.114000e+05  1.485000e+05
# 75%    42513.000000      0.450000  6.000000e+04   1.807000e+05  2.683500e+05
# max    56635.000000    160.060000  2.772000e+06   1.297180e+07  1.394040e+07
#
#           YearBuilt      Bedrooms      FullBath      HalfBath
# count  24163.000000  24157.000000  24275.000000  24144.000000
# mean    1963.744899      3.089912      1.886014      0.283921
# std       26.542982      0.852869      0.961515      0.487881
# ...

# %%
# From the counts we can see that some columns have empty cells

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56477 entries, 0 to 56476
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UniqueID         56477 non-null  int64
#  1   ParcelID         56477 non-null  object
#  2   LandUse          56477 non-null  object
#  3   PropertyAddress  56448 non-null  object
#  4   SaleDate         56477 non-null  object
#  5   SalePrice        56477 non-null  object
#  6   LegalReference   56477 non-null  object
#  7   SoldAsVacant     56477 non-null  object
#  8   OwnerName        25261 non-null  object
#  9   OwnerAddress     26015 non-null  object
#  10  Acreage          26015 non-null  float64
#  11  TaxDistrict      26015 non-null  object
#  12  LandValue        26015 non-null  float64
#  13  BuildingValue    26015 non-null  float64
#  14  TotalValue       26015 non-null  float64
#  15  YearBuilt        24163 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# UniqueID               0
# ParcelID               0
# LandUse                0
# PropertyAddress       29
# SaleDate               0
# SalePrice              0
# LegalReference         0
# SoldAsVacant           0
# OwnerName          31216
# OwnerAddress       30462
# Acreage            30462
# TaxDistrict        30462
# LandValue          30462
# BuildingValue      30462
# TotalValue         30462
# YearBuilt          32314
# Bedrooms           32320
# FullBath           32202
# HalfBath           32333
# dtype: int64

# %%
# We can delee rows with null values with this code <df_drop=df.dropna()> but fr the purpose of this project we will leave
# all nulls in place. I prefer leaving nulls in the dataset and ommitting them when doing analysis 
# where the nulls will affect the outcome of the results

# %% [markdown]
# __DROPPING DUPLICATE ROWS IF THEY EXIST__

# %%
# let's drop duplicate rows
df=df.drop_duplicates(keep='last')

# %% [markdown]
# __CHECKING IF THERE WERE DUPLICATES__
# We do this by re-checking the shape

# %%
df.shape
# Out:
# (56477, 19)

# %%
# The shape is still the same so there are no duplicates

# %% [markdown]
# __CHANGING DATE SaleDate COLUMN IN TO DATETIME SO PANDAS RECOGNIZES IT AS A DATE COLUMN__

# %%
df['SaleDate']=pd.to_datetime(df['SaleDate'])

# %% [markdown]
# __CHECKING__

# %%
df.head(1)
# Out:
#    UniqueID          ParcelID        LandUse  \
# 0       2045  007 00 0 125.00  SINGLE FAMILY
#
#                       PropertyAddress   SaleDate SalePrice    LegalReference  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09    240000  20130412-0036474
#
#   SoldAsVacant                  OwnerName  \
# 0           No  FRAZIER, CYRENTHA LYNETTE
#
#                              OwnerAddress  Acreage                TaxDistrict  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE, TN      2.3  GENERAL SERVICES DISTRICT
#
#    LandValue  BuildingValue  TotalValue  YearBuilt  Bedrooms  FullBath  \
# 0    50000.0       168200.0    235700.0     1986.0       3.0       3.0
#
#    HalfBath
# 0       0.0

# %%
#Splitting up the SaleDate colmun by the comma in the string
new=df["PropertyAddress"].str.split(",",n=1,expand=True)

# %% [markdown]
# __ASSIGNING NAMES TO SPLIT PARTS__

# %%
df["Street Name"]=new[0]

# %%
df["City"]=new[1]

# %% [markdown]
# __NOW LET'S DROPP THE SaleDate COLUMN__

# %%
df.drop(columns=["PropertyAddress"],inplace=True)

# %% [markdown]
# __CHECKING NEW COLUMNS__

# %%
df.columns
# Out:
# Index(['UniqueID ', 'ParcelID', 'LandUse', 'SaleDate', 'SalePrice',
#        'LegalReference', 'SoldAsVacant', 'OwnerName', 'OwnerAddress',
#        'Acreage', 'TaxDistrict', 'LandValue', 'BuildingValue', 'TotalValue',
#        'YearBuilt', 'Bedrooms', 'FullBath', 'HalfBath', 'Street Name', 'City'],
#       dtype='object')

# %% [markdown]
# __PRINTING SOME ROWS TO CHECK IF THE COMMA THAT WAS IN THE ADDRESS HAS BEEN REMOVED__

# %%
df.head(5)
# Out:
#    UniqueID          ParcelID        LandUse   SaleDate SalePrice  \
# 0       2045  007 00 0 125.00  SINGLE FAMILY 2013-04-09    240000
# 1      16918  007 00 0 130.00  SINGLE FAMILY 2014-06-10    366000
# 2      54582  007 00 0 138.00  SINGLE FAMILY 2016-09-26    435000
# 3      43070  007 00 0 143.00  SINGLE FAMILY 2016-01-29    255000
# 4      22714  007 00 0 149.00  SINGLE FAMILY 2014-10-10    278000
#
#      LegalReference SoldAsVacant                           OwnerName  \
# 0  20130412-0036474           No           FRAZIER, CYRENTHA LYNETTE
# 1  20140619-0053768           No             BONER, CHARLES & LESLIE
# 2  20160927-0101718           No           WILSON, JAMES E. & JOANNE
# 3  20160129-0008913           No            BAKER, JAY K. & SUSAN E.
# 4  20141015-0095255           No  POST, CHRISTOPHER M. & SAMANTHA C.
#
#                              OwnerAddress  Acreage                TaxDistrict  \
# ...

# %%
# It has been removed

# %% [markdown]
# __LET'S USE SAME METHOD TO SPLIT UP THE OwnerAddress__

# %%
new1=df["OwnerAddress"].str.split(",",n=1,expand=True)

# %%
df["Qwner_Street Name"]=new1[0]

# %%
df["Owner_City"]=new1[1]

# %%
df["Owner_State"]=new1[2]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     354                 try:
# --> 355                     return self._range.index(new_key)
#     356                 except ValueError as err:
#
# ValueError: 2 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-149-63183eb32529> in <module>
# ----> 1 df["Owner_State"]=new1[2]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
# ...

# %%
# I am getting an error because I have to split the second part. The syntax I used does not split the OwnerAddress column three ways as expected

# %%
df.head(5)
# Out:
#    UniqueID          ParcelID        LandUse   SaleDate SalePrice  \
# 0       2045  007 00 0 125.00  SINGLE FAMILY 2013-04-09    240000
# 1      16918  007 00 0 130.00  SINGLE FAMILY 2014-06-10    366000
# 2      54582  007 00 0 138.00  SINGLE FAMILY 2016-09-26    435000
# 3      43070  007 00 0 143.00  SINGLE FAMILY 2016-01-29    255000
# 4      22714  007 00 0 149.00  SINGLE FAMILY 2014-10-10    278000
#
#      LegalReference SoldAsVacant                           OwnerName  \
# 0  20130412-0036474           No           FRAZIER, CYRENTHA LYNETTE
# 1  20140619-0053768           No             BONER, CHARLES & LESLIE
# 2  20160927-0101718           No           WILSON, JAMES E. & JOANNE
# 3  20160129-0008913           No            BAKER, JAY K. & SUSAN E.
# 4  20141015-0095255           No  POST, CHRISTOPHER M. & SAMANTHA C.
#
#                              OwnerAddress  Acreage  ... BuildingValue  \
# 0  1808  FOX CHASE DR, GOODLETTSVILLE, TN      2.3  ...      168200.0
# ...

# %% [markdown]
# __SPLITTING Owner_City Column__

# %%
new3=df["Owner_City"].str.split(",",n=1,expand=True)

# %%
df["City"]=new1[0]

# %%
df["State"]=new1[1]

# %%
# Now let's drop Owner_City column and OwnerAddress

# %%
df.drop(columns=["Owner_City"],inplace=True)

# %%
df.drop(columns=["OwnerAddress"],inplace=True)

# %%
df.head(2)
# Out:
#    UniqueID          ParcelID        LandUse   SaleDate SalePrice  \
# 0       2045  007 00 0 125.00  SINGLE FAMILY 2013-04-09    240000
# 1      16918  007 00 0 130.00  SINGLE FAMILY 2014-06-10    366000
#
#      LegalReference SoldAsVacant                  OwnerName  Acreage  \
# 0  20130412-0036474           No  FRAZIER, CYRENTHA LYNETTE      2.3
# 1  20140619-0053768           No    BONER, CHARLES & LESLIE      3.5
#
#                  TaxDistrict  ...  BuildingValue  TotalValue  YearBuilt  \
# 0  GENERAL SERVICES DISTRICT  ...       168200.0    235700.0     1986.0
# 1  GENERAL SERVICES DISTRICT  ...       264100.0    319000.0     1998.0
#
#    Bedrooms  FullBath  HalfBath         Street Name                City  \
# 0       3.0       3.0       0.0  1808  FOX CHASE DR  1808  FOX CHASE DR
# 1       3.0       3.0       2.0  1832  FOX CHASE DR  1832  FOX CHASE DR
#
#     Qwner_Street Name                State
# 0  1808  FOX CHASE DR   GOODLETTSVILLE, TN
# ...

# %%
# Lets rename City and State columns to 'Owner_City' and 'Owner_State'

# %%
df.rename(columns={'City':'Owner_City', 'State':'Owner_State'})
# Out:
#        UniqueID           ParcelID                  LandUse   SaleDate  \
# 0           2045   007 00 0 125.00            SINGLE FAMILY 2013-04-09
# 1          16918   007 00 0 130.00            SINGLE FAMILY 2014-06-10
# 2          54582   007 00 0 138.00            SINGLE FAMILY 2016-09-26
# 3          43070   007 00 0 143.00            SINGLE FAMILY 2016-01-29
# 4          22714   007 00 0 149.00            SINGLE FAMILY 2014-10-10
# ...          ...               ...                      ...        ...
# 56472      30469  188 10 0A 101.00            SINGLE FAMILY 2015-05-27
# 56473      27707  188 10 0A 107.00            SINGLE FAMILY 2015-03-02
# 56474      52709  188 10 0A 118.00  VACANT RESIDENTIAL LAND 2016-08-16
# 56475      54042  188 10 0A 121.00  VACANT RESIDENTIAL LAND 2016-09-07
# 56476      54043  188 10 0A 122.00  VACANT RESIDENTIAL LAND 2016-09-07
#
#       SalePrice    LegalReference SoldAsVacant  \
# 0        240000  20130412-0036474           No
# ...

# %% [markdown]
# __SPLITTING UP THE OwnerName Column__

# %%
new4=df["OwnerName"].str.split(",",n=1,expand=True)

# %%
df["Owner's L Name"]=new4[0]

# %%
df["Owner's F&M Name"]=new4[1]

# %%
# Dropping 'OwnerName'
df.drop(columns=["OwnerName"],inplace=True)

# %%
df.head(5)
# Out:
#    UniqueID          ParcelID        LandUse   SaleDate SalePrice  \
# 0       2045  007 00 0 125.00  SINGLE FAMILY 2013-04-09    240000
# 1      16918  007 00 0 130.00  SINGLE FAMILY 2014-06-10    366000
# 2      54582  007 00 0 138.00  SINGLE FAMILY 2016-09-26    435000
# 3      43070  007 00 0 143.00  SINGLE FAMILY 2016-01-29    255000
# 4      22714  007 00 0 149.00  SINGLE FAMILY 2014-10-10    278000
#
#      LegalReference SoldAsVacant  Acreage                TaxDistrict  \
# 0  20130412-0036474           No      2.3  GENERAL SERVICES DISTRICT
# 1  20140619-0053768           No      3.5  GENERAL SERVICES DISTRICT
# 2  20160927-0101718           No      2.9  GENERAL SERVICES DISTRICT
# 3  20160129-0008913           No      2.6  GENERAL SERVICES DISTRICT
# 4  20141015-0095255           No      2.0  GENERAL SERVICES DISTRICT
#
#    LandValue  ...  YearBuilt  Bedrooms  FullBath  HalfBath  \
# 0    50000.0  ...     1986.0       3.0       3.0       0.0
# ...

# %%
# Listing unique values in SoldAsVacant column
print(df['SoldAsVacant'].unique())
# Out:
# ['No' 'N' 'Yes' 'Y']

# %%
# So let's convert 'N' to 'No' and 'Y' to 'Yes'

# %%
df[['SoldAsVacant']]=df[['SoldAsVacant']].replace('N','No')

# %%
df[['SoldAsVacant']]=df[['SoldAsVacant']].replace('Y','Yes')

# %% [markdown]
# __LET'S RE CHECK UNIQUE VALUES IN SoldAsVacant__

# %%
print(df['SoldAsVacant'].unique())
# Out:
# ['No' 'Yes']

# %% [markdown]
# __YAY....IT WORKED!!!!__

# %% [markdown]
# There are a lot of things we can do to the data but for the purpose of this project we will end here since what we have done is to introduce some basic methods that can be employed to clean up data.
# SEE YOU IN MY NEXT PROJECT

# %% [markdown]
# Now let us save the final file as a new csv file

# %%
df.to_csv('nash_housing_data_cleaned.csv',index=False)

# %% [markdown]
# __THE END THE END THE END THE END THE END THE END THE END THE END THE END THE END THE END THE END THE END THE END THE END__
